# %% [markdown]
# <a href="https://colab.research.google.com/github/HWatanuki/MatematicaAplicada/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd

# %%
X = [1,2,3,4,5,6]
Y = [8,0,7,1,10,-2]
Z = [0,8,1,7,-2,10]
C = [0,0,0,0,0,0]
d = {'X':X, 'Y':Y, 'Z':Z, 'C':C}

df = pd.DataFrame(data=d)
df
# Out:
#    X   Y   Z  C
# 0  1   8   0  0
# 1  2   0   8  0
# 2  3   7   1  0
# 3  4   1   7  0
# 4  5  10  -2  0
# 5  6  -2  10  0

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(X, Y, Z, 'blue')

ax.view_init(30, 30)
  
plt.show()
