# %% [markdown]
# <a href="https://colab.research.google.com/github/HWatanuki/MatematicaAplicada/blob/main/Limites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *
import numpy as np
init_printing(use_unicode=True)

# %%
#@title
def limite():
# vamos definir o símbolo x
  x = symbols('x')
# definimos a função
  f = (x ** 4 - 1) / (x ** 3- 1) 
# finalmente calculamos o limite
  limite = limit (f,x,1)
# e mostramos o resultado
  print ("O limite da função é: %f." % limite)
  deriv = diff(f)
  print (" dx/dt = ", deriv)

# %% [markdown]
# lim f(x)  x-> 1   x3 -1 / x2 - 1

# %%
#@title
limite()
# Out:
# O limite da função é: 1.333333.
#  dx/dt =  4*x**3/(x**3 - 1) - 3*x**2*(x**4 - 1)/(x**3 - 1)**2

# %%
#@title
x = symbols('x')
print (limit(1/x, x, 0, '+'))
print (limit(1/x,x,0,'-'))
p1 = plot (1/x, xlim = [-10,10], ylim=[-10, 10])
# Out:
# oo
# -oo

# %%
#@title
p2 = plot (sin(x), xlim = [-10,10], ylim= [-10,10])
p1.append(p2[0])
p1.show()

# %%
#@title
p3 = plot(x**2, (x, -10, 10))

# %%
#@title
t = symbols('t')
#plot_parametric ((t, cos(t)), (t, -10, 10))
plot_parametric ((cos(t), sin(t)), (t, -10, 10), aspect_ratio= [1,1])

# %%
#@title
x = symbols ('x')
y = symbols ('y')
plot (3 * x + 5, (t, -10, 10))
